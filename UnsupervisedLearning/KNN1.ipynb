# %%
import pandas as pd

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./Dataset/college_data")
df
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
df = df.iloc[:, 2:]
df
# Out:
#      Enroll  Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# 0       721         23         52         2885          537      7440
# 1       512         16         29         2683         1227     12280
# 2       336         22         50         1036           99     11250
# 3       137         60         89          510           63     12960
# 4        55         16         44          249          869      7560
# ..      ...        ...        ...          ...          ...       ...
# 772     543          4         26         3089         2029      6797
# 773     695         24         47         2849         1107     11520
# 774     695         34         61         2793          166      6900
# 775    1317         95         99         5217           83     19840
# 776     691         28         63         2988         1726      4990
#
#      Room.Board  Books  Personal  PhD  Terminal  S.F.Ratio  perc.alumni  \
# ...

# %%
model = KMeans(n_clusters=2)
model.fit(df, df.columns)
# Out:
# KMeans(n_clusters=2)

# %%
# model.labels_
model.cluster_centers_
# Out:
# array([[  462.65490798,    27.6196319 ,    55.41411043,  1932.16257669,
#           473.73312883, 11011.07668712,  4445.47699387,   545.85276074,
#          1249.66717791,    71.05368098,    78.31134969,    13.55153374,
#            24.19325153,  9884.99386503,    66.98466258],
#        [ 2435.104     ,    27.24      ,    57.792     , 12920.464     ,
#          2845.544     ,  7465.424     ,  3898.776     ,   567.784     ,
#          1815.168     ,    81.04      ,    86.96      ,    16.8968    ,
#            15.184     ,  8487.496     ,    57.528     ]])

# %%
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:, 1], marker="^", color="black")
